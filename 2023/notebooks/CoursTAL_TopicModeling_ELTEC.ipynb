# %% [markdown]
# https://github.com/COST-ELTeC/ELTeC-fra
#
# https://github.com/COST-ELTeC/ELTeC-fra-ext2

# %%
# !git clone https://github.com/COST-ELTeC/ELTeC-fra.git
# !git clone https://github.com/COST-ELTeC/ELTeC-fra-ext2.git
# Out:
# Cloning into 'ELTeC-fra'...
# remote: Enumerating objects: 6517, done.
# remote: Counting objects: 100% (665/665), done.
# remote: Compressing objects: 100% (160/160), done.
# remote: Total 6517 (delta 509), reused 659 (delta 504), pack-reused 5852
# Receiving objects: 100% (6517/6517), 181.27 MiB | 11.97 MiB/s, done.
# Resolving deltas: 100% (5225/5225), done.
# Updating files: 100% (308/308), done.
# Cloning into 'ELTeC-fra-ext2'...
# remote: Enumerating objects: 392, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 392 (delta 6), reused 9 (delta 4), pack-reused 339
# Receiving objects: 100% (392/392), 41.82 MiB | 15.71 MiB/s, done.
# Resolving deltas: 100% (126/126), done.

# %%
txt_folder_fra = "/content/ELTeC-fra/plain1"
txt_folder_fra_ext = "/content/ELTeC-fra-ext2/plain"

# %%
import glob

def fetch_eltec_fr(folder_name):
  docs = []
  for file in glob.glob(folder_name+"/*.txt"):
    with open(file, encoding="utf-8") as f:
      contents = f.read()
      #print(contents)
      print(file)
      docs.append(contents)
  return docs

# %%
docs_eltec_fr = fetch_eltec_fr(txt_folder_fra)
# Out:
# /content/ELTeC-fra/plain1/FRA00503_Balzac.txt
# /content/ELTeC-fra/plain1/FRA00901_Daudet.txt
# /content/ELTeC-fra/plain1/FRA02501_Loti.txt
# /content/ELTeC-fra/plain1/FRA05201_Feuillet.txt
# /content/ELTeC-fra/plain1/FRA00102_Adam.txt
# /content/ELTeC-fra/plain1/FRA02701_Maupassant.txt
# /content/ELTeC-fra/plain1/FRA06301_Montepin.txt
# /content/ELTeC-fra/plain1/FRA00401_Allais.txt
# /content/ELTeC-fra/plain1/FRA01302_Flaubert.txt
# /content/ELTeC-fra/plain1/FRA03201_Blandy.txt
# /content/ELTeC-fra/plain1/FRA01303_Flaubert.txt
# /content/ELTeC-fra/plain1/FRA07201_Montagne.txt
# /content/ELTeC-fra/plain1/FRA04901_Dumas.txt
# /content/ELTeC-fra/plain1/FRA04701_Bourget.txt
# /content/ELTeC-fra/plain1/FRA02401_LeRouge.txt
# /content/ELTeC-fra/plain1/FRA01501_France.txt
# /content/ELTeC-fra/plain1/FRA01202_Feval.txt
# /content/ELTeC-fra/plain1/FRA04801_Corday.txt
# /content/ELTeC-fra/plain1/FRA01403_Fleuriot.txt
# /content/ELTeC-fra/plain1/FRA04102_Erckmann.txt
# ...

# %%
docs_eltec_fr_ext = fetch_eltec_fr(txt_folder_fra_ext)
# Out:
# /content/ELTeC-fra-ext2/plain/FRA20000_Souza_Adele.txt
# /content/ELTeC-fra-ext2/plain/FRA20023_Sade_Justine.txt
# /content/ELTeC-fra-ext2/plain/FRA20086_Puget_Periphas.txt
# /content/ELTeC-fra-ext2/plain/FRA20030_Chevrier_Colporteur.txt
# /content/ELTeC-fra-ext2/plain/FRA20072_Riccoboni_Histoire.txt
# /content/ELTeC-fra-ext2/plain/FRA20019_Diderot_Religieuse.txt
# /content/ELTeC-fra-ext2/plain/FRA20024_Sade_Aline.txt
# /content/ELTeC-fra-ext2/plain/FRA20055_Marmontel_Belisaire.txt
# /content/ELTeC-fra-ext2/plain/FRA20080_Retif_Paysanne.txt
# /content/ELTeC-fra-ext2/plain/FRA20039_Senac_Emigre.txt
# /content/ELTeC-fra-ext2/plain/FRA20011_Crebillon_Nuit.txt
# /content/ELTeC-fra-ext2/plain/FRA20074_Riccoboni_LettresAdelaide.txt
# /content/ELTeC-fra-ext2/plain/FRA20025_Morelly_Naufrage.txt
# /content/ELTeC-fra-ext2/plain/FRA20020_Diderot_Jacques.txt
# /content/ELTeC-fra-ext2/plain/FRA20040_Dulaurens_Imirce.txt
# /content/ELTeC-fra-ext2/plain/FRA20098_Tiphaigne_Galligenes.txt
# ...

# %%
def eltec_fr_subset(docs, nb_sent):
  sub_docs = []
  for doc in docs:
    doc_lines = doc.split("\n")
    subcontent = '\n'.join(doc_lines[1:nb_sent])
    sub_docs.append(subcontent.replace(u'\xa0', u' '))
  return sub_docs

# %%
docs_eltec_fr_subset = eltec_fr_subset(docs_eltec_fr + docs_eltec_fr_ext, 50)

# %%
docs_eltec_fr_subset[0]
# Out:
# "CHAPITRE I -- VÉRONIQUE \nDans le Bas-Limoges, au coin de la rue de la Vieille-Poste et de la rue de la Cité, se trouvait, il y a trente ans, une de ces boutiques auxquelles il semble que rien n'ait été changé depuis le moyen âge. De grandes dalles cassées en mille endroits, posées sur le sol qui se montrait humide par places, auraient fait tomber quiconque n'eût pas observé les creux et les élévations de ce singulier carrelage. Les murs poudreux laissaient voir une bizarre mosaïque de bois, et de briques, de pierres et de fer tassés avec une solidité due au temps, peut-être au hasard. Le plancher, composé de poutres colossales, pliait depuis plus de cent ans sans rompre sous le poids des étages supérieurs. Bâtis en colombage, ces étages étaient à l'extérieur couverts en ardoises clouées de manière à dessiner des figures géométriques, et conservaient une image naïve des constructions bourgeoises du vieux temps. Aucune des croisées encadrées de bois, jadis brodées de sculptures aujou
# ...

# %% [markdown]
# Topic Modeling with LDA: Minimum Viable Example References:
#
# [1] LDA with Gensim: https://radimrehurek.com/gensim/models/ldamodel.html
#
# [2] Visualization with pyLDAvis: https://pypi.org/project/pyLDAvis/

# %%
# !pip install pyLDAvis
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 34.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 KB 29.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.1
#     Uninstalling joblib-1.1.1:
#       Successfully uninstalled joblib-1.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires joblib~=1.1.0, but you have joblib 1.2.0 which is incompatible.
# ...

# %%
# Import dependencies
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
import spacy
import pyLDAvis
import pyLDAvis.gensim_models
from sklearn.datasets import fetch_20newsgroups
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %%
# !pip install -U spacy
# !python -m spacy info
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-21 09:01:03.470052: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-21 09:01:03.470167: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
#!python -m spacy download fr_core_news_md
# !python -m spacy download fr_core_news_sm #plus petit modele
# Out:
# /usr/local/lib/python3.9/dist-packages/torch/cuda/__init__.py:497: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")
# 2023-03-21 09:08:47.186505: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2023-03-21 09:08:47.186657: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# ...

# %%
def lemmatize(docs, allowed_postags = ["NOUN", "ADJ", "VERB", "ADV"]):
  '''
  Performs lemmization of input documents.
  Args:
    - docs: list of strings with input documents
    - allowed_postags: list of accepted Part of Speech (POS) types
  Output:
    - list of strings with lemmatized input
  '''
  nlp = spacy.load("fr_core_news_sm", disable = ["parser", "ner"])
  nlp.max_length = 3000000 #this is possible as we're not using parser or ner.
  lemmatized_docs = []
  for doc in docs:
    doc = nlp(doc)
    tokens = []
    for token in doc:
      if token.pos_ in allowed_postags:
        tokens.append(token.lemma_)
    lemmatized_docs.append(" ".join(tokens))
  return (lemmatized_docs)

# %%
lemmatized_docs_eltec_fr = lemmatize(docs_eltec_fr_subset)

# %%
lemmatized_docs_eltec_fr[0]
# Out:
# "chapitre i véronique coin rue rue trouver avoir an boutique sembler ne changer moyen âge grand dalle casser endroit poser sol montrer humide place tomber quiconqu ne avoir pas observer creux élévation singulier carrelage mur poudreux laisser voir bizarre mosaïque bois brique pierre fer tasser solidité devoir temps peut-être hasard plancher composer poutre colossal plier plus an rompre poids étage supérieur colombage étage extérieur couvert ardoise clouer manière dessiner figure géométrique conserver image naïf construction bourgeois vieux temps croisée encadrer bois jadi broder sculpture aujourd'hui détruire intempérie atmosphère ne tenir aplomb une donner nez autre rentraient - une vouloir disjoindre tout terreau apporter ne savoir comment fente creuser pluie élancer printemps fleur léger timide plante grimpant herbe grêle mousse velouter toit appui pilier coin maçonnerie ce est - à - dire pierre mêler brique caillou effrayer regard courbure paraître devoir céder jour poids maison 
# ...

# %%
def tokenize(docs):
  '''
  Performs tokenization of input documents.
  Args:
    - docs: list of strings with input documents
  Output:
    - list of strings with tokenized input
  '''
  tokenized_docs = []
  for doc in docs:
    tokens = gensim.utils.simple_preprocess(doc, deacc=True)
    tokenized_docs.append(tokens)
  return (tokenized_docs)

# %%
tokenized_docs_eltec_fr = tokenize(lemmatized_docs_eltec_fr)

# %%
tokenized_docs_eltec_fr[0]
# Out:
# ['chapitre',
#  'veronique',
#  'coin',
#  'rue',
#  'rue',
#  'trouver',
#  'avoir',
#  'an',
#  'boutique',
#  'sembler',
#  'ne',
#  'changer',
#  'moyen',
#  'age',
#  'grand',
#  'dalle',
#  'casser',
#  'endroit',
#  'poser',
#  'sol',
#  'montrer',
#  'humide',
#  'place',
#  'tomber',
#  'quiconqu',
#  'ne',
#  'avoir',
#  'pas',
#  'observer',
#  'creux',
#  'elevation',
#  'singulier',
#  'carrelage',
#  'mur',
#  'poudreux',
#  'laisser',
#  'voir',
#  'bizarre',
#  'mosaique',
#  'bois',
#  'brique',
#  'pierre',
#  'fer',
#  'tasser',
#  'solidite',
#  'devoir',
#  'temps',
#  'peut',
#  'etre',
#  'hasard',
#  'plancher',
#  'composer',
#  'poutre',
#  'colossal',
#  'plier',
#  'plus',
#  'an',
#  'rompre',
#  'poids',
#  'etage',
#  'superieur',
#  'colombage',
#  'etage',
#  'exterieur',
#  'couvert',
#  'ardoise',
#  'clouer',
#  'maniere',
#  'dessiner',
#  'figure',
#  'geometrique',
#  'conserver',
#  'image',
#  'naif',
#  'construction',
#  'bourgeois',
# ...

# %%
# Mapping from word IDs to words
id2word = corpora.Dictionary(tokenized_docs_eltec_fr) 

# Prepare Document-Term Matrix
corpus = []
for doc in tokenized_docs_eltec_fr: 
    corpus.append(id2word.doc2bow(doc))

# Fit LDA model: 
topic_model = gensim.models.ldamodel.LdaModel(
    corpus = corpus,      # Document-Term Matrix
    id2word = id2word,    # Map word IDs to words
    num_topics = 100,      # Number of latent topics to extract
    random_state = 100,
    passes = 1000,         # N° of passes through the corpus during training
    )

# %%
print(lda_model.print_topics())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b38915d7e379> in <module>
# ----> 1 print(lda_model.print_topics())
#
# NameError: name 'lda_model' is not defined

# %%
# Visualize with pyLDAvis: See [2] for more details
pyLDAvis.enable_notebook()
visualization = pyLDAvis.gensim_models.prepare(
    topic_model, 
    corpus,
    id2word, 
    mds = "mmds", 
    R = 100)
# Out:
# /usr/local/lib/python3.9/dist-packages/pyLDAvis/_prepare.py:243: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   default_term_info = default_term_info.sort_values(
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %%
visualization
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 54     0.124558  0.385062       1        1  29.796207
# 64     0.183063  0.342007       2        1  23.273668
# 75    -0.054400  0.369339       3        1  15.008475
# 91     0.024944  0.397114       4        1  12.631994
# 80     0.381922  0.248756       5        1   3.623448
# ...         ...       ...     ...      ...        ...
# 65    -0.013319 -0.094623      96        1   0.000656
# 66    -0.013319 -0.094623      97        1   0.000656
# 67    -0.013319 -0.094623      98        1   0.000656
# 68    -0.013319 -0.094623      99        1   0.000656
# 0     -0.013319 -0.094623     100        1   0.000656
#
# [100 rows x 5 columns], topic_info=            Term         Freq        Total  Category   logprob   loglift
# 1842          ne  9020.000000  9020.000000   Default  100.0000  100.0000
# 2094        plus  3906.000000  3906.000000   Default   99.0000   99.0000
# ...

# %%
from gensim.models import CoherenceModel

coherence_model_lda = CoherenceModel(model=topic_model, texts=tokenized_docs_eltec_fr, dictionary=id2word)
coherence_lda = coherence_model_lda.get_coherence()
print('Coherence Score: ', coherence_lda)
# Out:
# Coherence Score:  0.32418971941113384

# %% [markdown]
# Pour un bon modèle LDA la cohérence doit être comprise entre 0.4 et 0.7 au-delà et en dessous le modèle est très probablement erroné.

# %%
# Fit LDA model: 
topic_model = gensim.models.ldamodel.LdaModel(
    corpus = corpus,      # Document-Term Matrix
    id2word = id2word,    # Map word IDs to words
    num_topics = 20,      # Number of latent topics to extract
    random_state = 100,
    passes = 1000,         # N° of passes through the corpus during training
    )

# %%
# Visualize with pyLDAvis: See [2] for more details
pyLDAvis.enable_notebook()
visualization = pyLDAvis.gensim_models.prepare(
    topic_model, 
    corpus,
    id2word, 
    mds = "mmds", 
    R = 20)
# Out:
# /usr/local/lib/python3.9/dist-packages/pyLDAvis/_prepare.py:243: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   default_term_info = default_term_info.sort_values(
# /usr/local/lib/python3.9/dist-packages/sklearn/manifold/_mds.py:299: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %%
visualization
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 15    -0.046245  0.241441       1        1  86.499097
# 5      0.273705 -0.104764       2        1   3.727143
# 14     0.193556  0.205330       3        1   3.049444
# 18    -0.258241 -0.090744       4        1   1.705320
# 2     -0.152979  0.168899       5        1   1.351892
# 13     0.016085  0.191416       6        1   1.034529
# 10     0.163308  0.024458       7        1   0.775525
# 0     -0.131473  0.024907       8        1   0.556477
# 11     0.056131  0.077408       9        1   0.516150
# 9     -0.043533  0.045816      10        1   0.434887
# 4     -0.021195 -0.166188      11        1   0.265410
# 17     0.001956 -0.086815      12        1   0.054321
# 8     -0.006384 -0.066396      13        1   0.003726
# 1     -0.006384 -0.066396      14        1   0.003726
# 12    -0.006384 -0.066396      15        1   0.003726
# 7     -0.006384 -0.066396      16        1   0.003726
# ...

# %%
from gensim.models import CoherenceModel

coherence_model_lda = CoherenceModel(model=topic_model, texts=tokenized_docs_eltec_fr, dictionary=id2word)
coherence_lda = coherence_model_lda.get_coherence()
print('Coherence Score: ', coherence_lda)
# Out:
# Coherence Score:  0.3227345204823262

# %% [markdown]
# Enlarge corpus size with Corpus Guttenberg
# - run Top2Vec
# - run BerTopic

# %%
# !pip install bertopic

# %% [markdown]
# Télécharger le fichier CSV disponible ici (https://www.kaggle.com/gpreda/tokyo-olympics-2020-tweets) et enregistrez-le dans votre dossier drive.

# %%
import pandas as pd 
import numpy as np
from bertopic import BERTopic

# %%
# !ls /content/drive/MyDrive/Colab\ Notebooks/data/

# %%
import pandas as pd 
 
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/data/tokyo_2020_tweets.csv", engine='python')
 
# select only 6000 tweets 
df_6000 = df[0:6000]

# %%
# create model 
 
model = BERTopic(verbose=True)
 
#convert to list 
docs = df_6000.text.to_list()
 
topics, probabilities = model.fit_transform(docs)

# %%
model.get_topic_freq().head(11)

# %%
model.get_topic(22)

# %%
model.visualize_topics()

# %%
model.visualize_barchart()

# %%
model.visualize_heatmap()

# %%
#model = BERTopic(nr_topics=20)

# %%
#model = BERTopic(nr_topics="auto")

# %%
#new_topics, new_probs = model.reduce_topics(docs, topics, probabilities, nr_topics=15)

# %% [markdown]
# Make Prediction

# %%
df_prediction = df[6015:6025]
new_docs = df_prediction.text.to_list()
topics, probs = model.transform(new_docs)

# %%
print(new_docs)
print(topics)

# %%
model.save("my_topics_model")
BerTopic_model = BERTopic.load("my_topics_model")
