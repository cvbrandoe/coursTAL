# %%
# !pip install bertopic
# Out:
# Requirement already satisfied: bertopic in /usr/local/lib/python3.7/dist-packages (0.9.4)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.7/dist-packages (from bertopic) (4.63.0)
# Requirement already satisfied: pyyaml<6.0 in /usr/local/lib/python3.7/dist-packages (from bertopic) (5.4.1)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.7/dist-packages (from bertopic) (1.0.2)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from bertopic) (1.3.5)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.7/dist-packages (from bertopic) (5.5.0)
# Requirement already satisfied: hdbscan>=0.8.27 in /usr/local/lib/python3.7/dist-packages (from bertopic) (0.8.28)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.7/dist-packages (from bertopic) (1.21.5)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from bertopic) (2.2.0)
# Requirement already satisfied: umap-learn>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from bertopic) (0.5.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.27->bertopic) (1.4.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.27->bertopic) (1.1.0)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.7/dist-packages (from hdbscan>=0.8.27->bertopic) (0.29.28)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=1.1.5->bertopic) (2018.9)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from plotly>=4.7.0->bertopic) (8.0.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from plotly>=4.7.0->bertopic) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.4.0)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic) (4.17.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.2.5)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic) (1.10.0+cu111)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.11.1+cu111)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.1.96)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.6.0->sentence-transformers>=0.4.1->bertopic) (3.10.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2.23.0)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.0.47)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (4.11.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (21.3)
# Requirement already satisfied: tokenizers!=0.11.3,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (0.11.6)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2019.12.20)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.0.7)
# Requirement already satisfied: pynndescent>=0.5 in /usr/local/lib/python3.7/dist-packages (from umap-learn>=0.5.0->bertopic) (0.5.6)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from umap-learn>=0.5.0->bertopic) (0.51.2)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.34.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (57.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (1.24.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (7.1.2)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (7.1.2)

# %% [markdown]
# Télécharger le fichier CSV disponible ici (https://www.kaggle.com/gpreda/tokyo-olympics-2020-tweets) et enregistrez-le dans votre dossier drive.

# %%
import pandas as pd 
import numpy as np
from bertopic import BERTopic

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls /content/drive/MyDrive/Colab\ Notebooks/data/
# Out:
# tokyo_2020_tweets.csv

# %%
import pandas as pd 
 
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/data/tokyo_2020_tweets.csv", engine='python')
 
# select only 6000 tweets 
df_6000 = df[0:6000]

# %%
# create model 
 
model = BERTopic(verbose=True)
 
#convert to list 
docs = df_6000.text.to_list()
 
topics, probabilities = model.fit_transform(docs)
# Out:
# Batches:   0%|          | 0/188 [00:00<?, ?it/s]
# 2022-03-09 09:27:18,915 - BERTopic - Transformed documents to Embeddings
# 2022-03-09 09:27:39,233 - BERTopic - Reduced dimensionality with UMAP
# 2022-03-09 09:27:39,570 - BERTopic - Clustered UMAP embeddings with HDBSCAN

# %%
model.get_topic_freq().head(11)
# Out:
#     Topic  Count
# 0      -1   1684
# 1       0    276
# 2       1    232
# 3       2    223
# 4       3    207
# 5       4    164
# 6       5    100
# 7       6    100
# 8       7     91
# 9       8     88
# 10      9     85

# %%
model.get_topic(22)
# Out:
# [('hockey', 0.1263343310132279),
#  ('africa', 0.04918784464802913),
#  ('south', 0.04677426541902326),
#  ('11', 0.04239655864763759),
#  ('quarter', 0.039347750391876025),
#  ('rsa', 0.03766021328677206),
#  ('men', 0.036265203263899884),
#  ('teamgb', 0.03289493073503809),
#  ('germany', 0.029133667509209024),
#  ('britain', 0.028463637172598227)]

# %%
model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="09bf2ace-1b79-461d-8d49-8d7e4b183bf6" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("09bf2ace-1b79-461d-8d49-8d7e4b183bf6")) {                    Plotly.newPlot(                        "09bf2ace-1b79-461d-8d49-8d7e4b183bf6",                        [{"customdata":[[0,"tokyo2020 | you | im | lets | grande",306],[1,"vikas | boxing | krishan | okazawa | round",221],[2,"proud | mirabaichanu | you | moment | indians",213],[3,"hearty | lifting | puneethrajkumar | 49kg | weightlifting",207],[4,"olympics | olympicgames | tokyo2020 | games | athletes",206],[5,"race | road | carapaz | cyclingroad | richard",109],[6,"swimming | tokyotogether | swim | my | is",88],[7,"banda | barbra | hattricks | two | barbara",87],[8,"zambia | china | 44 | wang | banda",78],[9,"clareburt | lewis | smith | brendon | 400m",77],[10,"weightlifting | silver | winning | 49 | kg",77],[11,"bbc | coverage | eurosport | bbcolympics | live",73],[12,"q2 | 11 | 21 | live | ger",72],[13,"100m | butterfly | heat | fly | walshe",71],[14,"swevaus | space | six | damn | furniture",66],[15,"kosovo | krasniqi | distria | gold | judo",62],[16,"ongoing | many | indias | winning | first",62],[17,"winning | indian | silver | weightlifting | ace",62],[18,"football | japan | women | hosts | team",60],[19,"yulo | rings | carlos | caloy | 14000",60],[20,"kerr | sam | penalty | matildas | lindahl",54],[21,"teamgb | japan | gb | football | team",54],[22,"hockey | africa | south | 11 | quarter",51],[23,"medal | indias | india | first | congratulations",49],[24,"badminton | sokongmalaysia | malaysia | double | ganbattemalaysia",48],[25,"made | country
ated","90_covid19_vaccine_vaccinated","91_adam_peaty_pool","92_taekwondo_kurt_barbosa","93_wining_phenomenal_perfor...","94_saikhom_weightlift_day","95_thematildas_wearematilda...","96_stupendous_asked_elated","97_handball_egypt_esp","98_movies_hollywoodciak_cel...","99_tally_medals_cheer4india","100_swedes_swevaus_swedish","101_term_roadmap_realgolden...","102_butterfly_semifinals_rule","103_jobs_ngo_vacancy","104_cilic_menezes_marin","105_weeks_hours_going","106_wakey_ready_be"],"y":["-1_the_olympics_and","0_tokyo2020_you_im","1_vikas_boxing_krishan","2_proud_mirabaichanu_you","3_hearty_lifting_puneethraj...","4_olympics_olympicgames_tok...","5_race_road_carapaz","6_swimming_tokyotogether_swim","7_banda_barbra_hattricks","8_zambia_china_44","9_clareburt_lewis_smith","10_weightlifting_silver_win...","11_bbc_coverage_eurosport","12_q2_11_21","13_100m_butterfly_heat","14_swevaus_space_six","15_kosovo_krasniqi_distria","16_ongoing_many_indias","17_winning_indian_silver","18 ...

# %%
#model = BERTopic(nr_topics=20)

# %%
#model = BERTopic(nr_topics="auto")

# %%
#new_topics, new_probs = model.reduce_topics(docs, topics, probabilities, nr_topics=15)

# %% [markdown]
# Make Prediction

# %%
df_prediction = df[6015:6025]
new_docs = df_prediction.text.to_list()
topics, probs = model.transform(new_docs)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2022-03-09 10:06:11,383 - BERTopic - Reduced dimensionality with UMAP
# 2022-03-09 10:06:11,388 - BERTopic - Predicted clusters with HDBSCAN

# %%
print(new_docs)
print(topics)
# Out:
# ['#Tokyo2020 rubbish penalty against Zambia 🇿🇲 #football #Olympics2021', 'Why don’t they let Japan have the Olympics in 2028 so they can have the true experience for their people? #Tokyo2020', 'Do you know that the Czech team🇨🇿 olympic clothing💃🕺🎎 is rated in the TOP 6👍🥳👏🙌 #OlympicGames #Clothing contest of… https://t.co/14HYtcSpBu', 'Weightlifter Mirabai Chanu has secured first medal 🥈for the country at #Tokyo2020\xa0  Olympics, winning the silver me… https://t.co/A12EaaO7pN', '52’ Goallll Lina Hurtig equalizes for Sweden, her 2nd goal of the tournament \n\nSweden 2-2 Australia \n\nWomen’s Summer Olympics #Tokyo2020', 'Big fan of the hats the Korean team are wearing. #Archery #Tokyo2020', "🥊@kurtwalker7 has a tough draw against Uzbekistan's Mirazizbek Mirzakhalilov in the next round, but @ericdonovanbox… https://t.co/lyNy5BwCQC", '"I am really happy on winning a 🥈 medal in #Tokyo2020 for my country"- @mirabai_chanu \n#OlympicGames #TeamIndia… https://t.co/KFBECNForS', 'PM Modiji invited ANI and asked them to video shoot this moment ? Good PR.\n #Tokyo2020 \n #Tokyo2021… https://t.co/VnWC1Ypr2F', '@PuneethRajkumar @mirabai_chanu Boss\n\n#Dvitva #James @PuneethRajkumar\n\n#TokyoOlympics\n#Cheer4India\n#Tokyo2020\n#TeamIndia 22']
# [8, 4, -1, -1, -1, 69, -1, -1, 0, 36]

# %%
model.save("my_topics_model")
BerTopic_model = BERTopic.load("my_topics_model")
